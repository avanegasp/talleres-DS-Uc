# %% [markdown]
# <a href="https://colab.research.google.com/github/avanegasp/talleres-DS-Uc/blob/main/Copia_de_Temas_avanzados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src = "https://github.com/HarryVargas96/UdeCataluna/blob/main/logo_uc_grande.png?raw=true" alt = "Encabezado" width = "100%">  </img>

# %% [markdown]
# ## 1. Dependencias

# %%
import joblib

# Librerías usuales
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#
import sklearn
from sklearn.model_selection import (train_test_split, GridSearchCV, RandomizedSearchCV,
                                     RepeatedStratifiedKFold, cross_validate)

# Assemble pipeline(s)
from sklearn import set_config
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, OrdinalEncoder

# Models
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error
set_config(display="diagram")

# %%
# !python --version
print('NumPy', np.__version__)
print('Pandas', pd.__version__)
print('Sci-kit learn',sklearn.__version__)
# Out:
# Python 3.10.12
# NumPy 1.23.5
# Pandas 1.5.3
# Sci-kit learn 1.2.2

# %% [markdown]
# ## 2. Lectura de datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Lectura de archivo crudo
df = pd.read_csv(
    'https://github.com/HarryVargas96/UdeCataluna/blob/main/data/airbnb.csv?raw=true',
    delimiter=',')

# %% [markdown]
# ## 3. Limpieza de datos

# %%
# Filtro de datos erróneos
df = df[df['price'] > 0].copy()
# Selección de características
df = df[
    ['price','neighbourhood','latitude','longitude', 'property_type'
    ,'room_type','bathrooms','bedrooms','beds','host_is_superhost','parking' ]
    ]
# Limpieza de variable
df['parking'].replace({-1.0 : 0.0 } , inplace = True)

# %%
# Cambio de tipología
df = df.astype(
    {
        'host_is_superhost':'object',
        'parking': 'object'
    }
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30173 entries, 0 to 30178
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price              30173 non-null  int64
#  1   neighbourhood      30164 non-null  object
#  2   latitude           30173 non-null  float64
#  3   longitude          30173 non-null  float64
#  4   property_type      30173 non-null  object
#  5   room_type          30173 non-null  object
#  6   bathrooms          30173 non-null  float64
#  7   bedrooms           30173 non-null  int64
#  8   beds               30173 non-null  int64
#  9   host_is_superhost  30164 non-null  category
#  10  parking            30173 non-null  category
# dtypes: category(2), float64(3), int64(3), object(3)
# memory usage: 2.4+ MB

# %% [markdown]
# ## 4. Partición prueba y entrenamiento

# %%
X = df.drop(columns = 'price')
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size = 0.3,
    random_state = 0
  )

# %% [markdown]
# ## 5. Pipelines preprocesamiento

# %%
# Columnas numéricas
numeric_cols = list(X_train.select_dtypes(include=np.number).columns)
# Columnas categóricas
cat_cols = list(X_train.select_dtypes(include=['object']).columns)

# %%
numeric_cols
# Out:
# ['latitude', 'longitude', 'bathrooms', 'bedrooms', 'beds']

# %%
cat_cols
# Out:
# ['neighbourhood', 'property_type', 'room_type', 'host_is_superhost', 'parking']

# %%
# Pipeline para variables numéricas
pipeline_numerico = Pipeline(
    [('imputador', SimpleImputer(strategy = 'median')),
     ('escalador', StandardScaler())]
     )

pipeline_numerico
# Out:
# Pipeline(steps=[('imputador', SimpleImputer(strategy='median')),
#                 ('escalador', StandardScaler())])

# %%
pipeline_numerico.fit_transform(X_train[['latitude','longitude']])
# Out:
# array([[ 0.06222692,  4.69670681],
#        [-0.8680187 ,  0.89020859],
#        [ 1.8564551 ,  1.10574337],
#        ...,
#        [-0.33663282, -0.14603375],
#        [ 0.9115657 ,  0.10210293],
#        [-0.65806362,  0.61082841]])

# %%
# Pipeline para categóricas con Dummy
pipeline_categorico = Pipeline(
    [('imputador', SimpleImputer(strategy='most_frequent')),
     ('codificador', OneHotEncoder(drop='first', handle_unknown='ignore'))]
    )

pipeline_categorico
# Out:
# Pipeline(steps=[('imputador', SimpleImputer(strategy='most_frequent')),
#                 ('codificador',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))])

# %%
# Unir las transformaciones previas en un Pipeline más grande

preprocesamiento = ColumnTransformer(
    [('variables_numericas', pipeline_numerico, numeric_cols),
     ('variables_categoricas', pipeline_categorico, cat_cols)])
preprocesamiento
# Out:
# ColumnTransformer(transformers=[('variables_numericas',
#                                  Pipeline(steps=[('imputador',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('escalador',
#                                                   StandardScaler())]),
#                                  ['latitude', 'longitude', 'bathrooms',
#                                   'bedrooms', 'beds']),
#                                 ('variables_categoricas',
#                                  Pipeline(steps=[('imputador',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('codificador',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  ['neighbourhood', 'property_type', 'room_type',
#                                   'host_is_superhost', 'parking'])])

# %% [markdown]
# ## 6. Pipeline Modelamiento

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_pipe = Pipeline(
    [('preprocesamiento', preprocesamiento),
     ('regresor', KNeighborsRegressor())]
     )

model_pipe
# Out:
# Pipeline(steps=[('preprocesamiento',
#                  ColumnTransformer(transformers=[('variables_numericas',
#                                                   Pipeline(steps=[('imputador',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('escalador',
#                                                                    StandardScaler())]),
#                                                   ['latitude', 'longitude',
#                                                    'bathrooms', 'bedrooms',
#                                                    'beds']),
#                                                  ('variables_categoricas',
#                                                   Pipeline(steps=[('imputador',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('codificador',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['neighbourhood',
#                                                    'property_type', 'room_type',
#                                                    'host_is_superhost',
#                                                    'parking'])])),
#                 ('regresor', KNeighborsRegressor())])

# %% [markdown]
# ### GridSearchCV

# %%
np.logspace(-10,10, num = 10)
# Out:
# array([1.00000000e-10, 1.66810054e-08, 2.78255940e-06, 4.64158883e-04,
#        7.74263683e-02, 1.29154967e+01, 2.15443469e+03, 3.59381366e+05,
#        5.99484250e+07, 1.00000000e+10])

# %%
param_grid = [
              {'regresor': [KNeighborsRegressor()],
               'regresor__n_neighbors': np.linspace(1, 30, num = 30, dtype=int)#30
              },
              {'regresor': [DecisionTreeRegressor(random_state=0)],
               'regresor__max_depth': np.linspace(1, 30, num = 30, dtype=int)# 30
              },
              {'regresor': [RandomForestRegressor(n_jobs=-1, random_state=0)],
               'regresor__n_estimators': np.linspace(100, 400, num = 4, dtype=int),
               'regresor__max_depth': np.linspace(1, 10, num = 4, dtype=int),
               'regresor__max_features': np.linspace(1, 10, num = 3, dtype=int),# 48
               'regresor__min_samples_leaf': [5]
              },
              {'regresor': [LinearRegression()] # 1
              }
              ] # 109 experimentos

scores = [
    'neg_root_mean_squared_error',
    'neg_mean_absolute_error',
    'r2'
    ]

# %%
grid_search = GridSearchCV(
    model_pipe,
    param_grid,
    cv=5,# 545 experimentos
    scoring=scores,
    refit= 'neg_root_mean_squared_error' ,
    n_jobs=-1,
    verbose = 3,
    )
grid_search
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocesamiento',
#                                         ColumnTransformer(transformers=[('variables_numericas',
#                                                                          Pipeline(steps=[('imputador',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('escalador',
#                                                                                           StandardScaler())]),
#                                                                          ['latitude',
#                                                                           'longitude',
#                                                                           'bathrooms',
#                                                                           'bedrooms',
#                                                                           'beds']),
#                                                                         ('variables_categoricas',
#                                                                          Pipeline(steps=[('imputador',
#                                                                                           SimpleImputer(strategy='m...
#                          {'regresor': [RandomForestRegressor(n_jobs=-1,
#                                                              random_state=0)],
#                           'regresor__max_depth': array([ 1,  4,  7, 10]),
#                           'regresor__max_features': array([ 1,  5, 10]),
#                           'regresor__min_samples_leaf': [5],
#                           'regresor__n_estimators': array([100, 200, 300, 400])},
#                          {'regresor': [LinearRegression()]}],
#              refit='neg_root_mean_squared_error',
#              scoring=['neg_root_mean_squared_error', 'neg_mean_absolute_error',
#                       'r2'],
#              verbose=3)

# %% [markdown]
# Esta celda tardó 28 minutos en ejecutarse

# %%
# %%time
grid_search.fit(X_train,y_train)
joblib.dump(grid_search,
            '/content/drive/MyDrive/Diplomado big data/model_grid.joblib')

# %%
grid_search = joblib.load('/content/drive/MyDrive/Diplomado big data/model_grid.joblib')

# %%
random_grid_search = RandomizedSearchCV(
    model_pipe,
    param_grid,
    cv=5,# 545 experimentos
    scoring=scores,
    refit= 'neg_root_mean_squared_error' ,
    n_jobs=-1,
    verbose = 3,
    n_iter = 3
    )
random_grid_search
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocesamiento',
#                                               ColumnTransformer(transformers=[('variables_numericas',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('escalador',
#                                                                                                 StandardScaler())]),
#                                                                                ['latitude',
#                                                                                 'longitude',
#                                                                                 'bathrooms',
#                                                                                 'bedrooms',
#                                                                                 'beds']),
#                                                                               ('variables_categoricas',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strat...
#                                         {'regresor': [RandomForestRegressor(n_jobs=-1,
#                                                                             random_state=0)],
#                                          'regresor__max_depth': array([ 1,  4,  7, 10]),
#                                          'regresor__max_features': array([ 1,  5, 10]),
#                                          'regresor__min_samples_leaf': [5],
#                                          'regresor__n_estimators': array([100, 200, 300, 400])},
#                                         {'regresor': [LinearRegression()]}],
#                    refit='neg_root_mean_squared_error',
#                    scoring=['neg_root_mean_squared_error',
#                             'neg_mean_absolute_error', 'r2'],
#                    verbose=3)

# %%
# %%time
random_grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# CPU times: user 1 s, sys: 83.7 ms, total: 1.09 s
# Wall time: 21.1 s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocesamiento',
#                                               ColumnTransformer(transformers=[('variables_numericas',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('escalador',
#                                                                                                 StandardScaler())]),
#                                                                                ['latitude',
#                                                                                 'longitude',
#                                                                                 'bathrooms',
#                                                                                 'bedrooms',
#                                                                                 'beds']),
#                                                                               ('variables_categoricas',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strat...
#                                         {'regresor': [RandomForestRegressor(n_jobs=-1,
#                                                                             random_state=0)],
#                                          'regresor__max_depth': array([ 1,  4,  7, 10]),
#                                          'regresor__max_features': array([ 1,  5, 10]),
#                                          'regresor__min_samples_leaf': [5],
#                                          'regresor__n_estimators': array([100, 200, 300, 400])},
#                                         {'regresor': [LinearRegression()]}],
#                    refit='neg_root_mean_squared_error',
#                    scoring=['neg_root_mean_squared_error',
#                             'neg_mean_absolute_error', 'r2'],
#                    verbose=3)

# %%
dir(random_grid_search)
# best_estimator_
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_'

# %%
random_grid_search.cv_results_

# %%
results = pd.DataFrame(random_grid_search.cv_results_)

# %%
pd.set_option('display.max_columns', 500)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       3.248019      0.139111         0.306036        0.042577
# 1       2.202196      0.655153         0.054397        0.019793
# 2       0.735218      0.266750         0.031403        0.006013
#
#   param_regresor__n_estimators param_regresor__min_samples_leaf  \
# 0                          400                                5
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#
#   param_regresor__max_features param_regresor__max_depth  \
# 0                            5                        10
# 1                          NaN                        24
# 2                          NaN                        14
#
#                                       param_regresor  \
# 0   RandomForestRegressor(n_jobs=-1, random_state=0)
# 1  DecisionTreeRegressor(max_depth=14, random_sta...
# 2  DecisionTreeRegressor(max_depth=14, random_sta...
#
#                                               params  \
# 0  {'regresor__n_estimators': 400, 'regresor__min...
# 1  {'regresor__max_depth': 24, 'regresor': Decisi...
# 2  {'regresor__max_depth': 14, 'regresor': Decisi...
#
#    split0_test_neg_root_mean_squared_error  \
# 0                               -79.151628
# 1                               -78.592521
# 2                               -70.346090
#
#    split1_test_neg_root_mean_squared_error  \
# 0                               -76.964191
# 1                               -78.137231
# 2                               -70.590718
#
#    split2_test_neg_root_mean_squared_error  \
# 0                               -78.791901
# 1                               -78.789622
# 2                               -71.301207
#
#    split3_test_neg_root_mean_squared_error  \
# 0                               -79.736300
# 1                               -79.552119
# 2                               -70.833859
#
#    split4_test_neg_root_mean_squared_error  \
# 0                               -77.159160
# 1                               -78.767257
# 2                               -68.733324
#
#    mean_test_neg_root_mean_squared_error  \
# 0                             -78.360636
# 1                             -78.767750
# 2                             -70.361040
#
#    std_test_neg_root_mean_squared_error  \
# 0                              1.104329
# 1                              0.456940
# 2                              0.872915
#
#    rank_test_neg_root_mean_squared_error  split0_test_neg_mean_absolute_error  \
# 0                                      2                           -58.502332
# 1                                      3                           -49.801526
# 2                                      1                           -43.988788
#
#    split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  \
# 0                           -57.166423                           -58.116618
# 1                           -50.618240                           -51.017233
# 2                           -44.571859                           -44.727981
#
#    split3_test_neg_mean_absolute_error  split4_test_neg_mean_absolute_error  \
# 0                           -58.898313                           -57.162909
# 1                           -50.503099                           -49.941341
# 2                           -44.279177                           -42.982466
#
#    mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  \
# 0                         -57.969319                          0.701964
# 1                         -50.376288                          0.448322
# 2                         -44.110054                          0.618039
#
#    rank_test_neg_mean_absolute_error  split0_test_r2  split1_test_r2  \
# 0                                  3        0.283589        0.292568
# 1                                  2        0.293674        0.270839
# 2                                  1        0.434122        0.404883
#
#    split2_test_r2  split3_test_r2  split4_test_r2  mean_test_r2  std_test_r2  \
# 0        0.281565        0.290615        0.302228      0.290113     0.007330
# 1        0.281607        0.293888        0.272840      0.282570     0.009845
# 2        0.411674        0.440176        0.446301      0.427431     0.016248
#
#    rank_test_r2
# 0             2
# 1             3
# 2             1

# %%
random_grid_search
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocesamiento',
#                                               ColumnTransformer(transformers=[('variables_numericas',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('escalador',
#                                                                                                 StandardScaler())]),
#                                                                                ['latitude',
#                                                                                 'longitude',
#                                                                                 'bathrooms',
#                                                                                 'bedrooms',
#                                                                                 'beds']),
#                                                                               ('variables_categoricas',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strat...
#                                         {'regresor': [RandomForestRegressor(n_jobs=-1,
#                                                                             random_state=0)],
#                                          'regresor__max_depth': array([ 1,  4,  7, 10]),
#                                          'regresor__max_features': array([ 1,  5, 10]),
#                                          'regresor__min_samples_leaf': [5],
#                                          'regresor__n_estimators': array([100, 200, 300, 400])},
#                                         {'regresor': [LinearRegression()]}],
#                    refit='neg_root_mean_squared_error',
#                    scoring=['neg_root_mean_squared_error',
#                             'neg_mean_absolute_error', 'r2'],
#                    verbose=3)

# %%
random_grid_search.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# array([118.73333333,  63.84534271, 176.85714286, ...,  76.50202429,
#        122.65517241, 377.53333333])

# %%
grid_search.best_score_
# Out:
# -60.34965974456511

# %%
grid_search.best_estimator_['regresor'].get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 7,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 0,
#  'splitter': 'best'}

# %%
pd.DataFrame(grid_search.cv_results_).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 35 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   mean_fit_time                            109 non-null    float64
#  1   std_fit_time                             109 non-null    float64
#  2   mean_score_time                          109 non-null    float64
#  3   std_score_time                           109 non-null    float64
#  4   param_regresor                           109 non-null    object
#  5   param_regresor__n_neighbors              30 non-null     object
#  6   param_regresor__max_depth                78 non-null     object
#  7   param_regresor__max_features             48 non-null     object
#  8   param_regresor__min_samples_leaf         48 non-null     object
#  9   param_regresor__n_estimators             48 non-null     object
#  10  params                                   109 non-null    object
#  11  split0_test_neg_root_mean_squared_error  109 non-null    float64
#  12  split1_test_neg_root_mean_squared_error  109 non-null    float64
#  13  split2_test_neg_root_mean_squared_error  109 non-null    float64
#  14  split3_test_neg_root_mean_squared_error  109 non-null    float64
#  15  split4_test_neg_root_mean_squared_error  109 non-null    float64
#  16  mean_test_neg_root_mean_squared_error    109 non-null    float64
#  17  std_test_neg_root_mean_squared_error     109 non-null    float64
#  18  rank_test_neg_root_mean_squared_error    109 non-null    int32
#  19  split0_test_neg_mean_absolute_error      109 non-null    float64
#  20  split1_test_neg_mean_absolute_error      109 non-null    float64
#  21  split2_test_neg_mean_absolute_error      109 non-null    float64
#  22  split3_test_neg_mean_absolute_error      109 non-null    float64
#  23  split4_test_neg_mean_absolute_error      109 non-null    float64
#  24  mean_test_neg_mean_absolute_error        109 non-null    float64
#  25  std_test_neg_mean_absolute_error         109 non-null    float64
#  26  rank_test_neg_mean_absolute_error        109 non-null    int32
#  27  split0_test_r2                           109 non-null    float64
#  28  split1_test_r2                           109 non-null    float64
#  29  split2_test_r2                           109 non-null    float64
#  30  split3_test_r2                           109 non-null    float64
#  31  split4_test_r2                           109 non-null    float64
#  32  mean_test_r2                             109 non-null    float64
#  33  std_test_r2                              109 non-null    float64
#  34  rank_test_r2                             109 non-null    int32
# dtypes: float64(25), int32(3), object(7)
# memory usage: 28.7+ KB

# %%
pd.DataFrame(grid_search.cv_results_).nlargest(10,'mean_test_neg_root_mean_squared_error')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 36       0.205031      0.007296         0.027261        0.001213
# 20       0.093472      0.016020        15.440704        1.187727
# 19       0.087847      0.007705        14.494968        0.165982
# 15       0.139526      0.033960        15.179213        1.516705
# 21       0.115820      0.040407        14.173107        0.320685
# 18       0.083013      0.001134        14.543803        0.205711
# 16       0.140394      0.039536        14.258273        0.298650
# 14       0.145024      0.032776        14.039270        0.156281
# 17       0.093734      0.019132        14.470613        0.067480
# 28       0.082988      0.000629        14.512605        0.101326
#
#                                        param_regresor  \
# 36  DecisionTreeRegressor(max_depth=7, random_stat...
# 20                              KNeighborsRegressor()
# 19                              KNeighborsRegressor()
# 15                              KNeighborsRegressor()
# 21                              KNeighborsRegressor()
# 18                              KNeighborsRegressor()
# 16                              KNeighborsRegressor()
# 14                              KNeighborsRegressor()
# 17                              KNeighborsRegressor()
# 28                              KNeighborsRegressor()
#
#    param_regresor__n_neighbors param_regresor__max_depth  \
# 36                         NaN                         7
# 20                          21                       NaN
# 19                          20                       NaN
# 15                          16                       NaN
# 21                          22                       NaN
# 18                          19                       NaN
# 16                          17                       NaN
# 14                          15                       NaN
# 17                          18                       NaN
# 28                          29                       NaN
#
#    param_regresor__max_features param_regresor__min_samples_leaf  \
# 36                          NaN                              NaN
# 20                          NaN                              NaN
# 19                          NaN                              NaN
# 15                          NaN                              NaN
# 21                          NaN                              NaN
# 18                          NaN                              NaN
# 16                          NaN                              NaN
# 14                          NaN                              NaN
# 17                          NaN                              NaN
# 28                          NaN                              NaN
#
#    param_regresor__n_estimators  ... std_test_neg_mean_absolute_error  \
# 36                          NaN  ...                         0.479057
# 20                          NaN  ...                         0.571323
# 19                          NaN  ...                         0.600627
# 15                          NaN  ...                         0.660137
# 21                          NaN  ...                         0.549013
# 18                          NaN  ...                         0.666460
# 16                          NaN  ...                         0.687670
# 14                          NaN  ...                         0.675684
# 17                          NaN  ...                         0.693659
# 28                          NaN  ...                         0.422409
#
#     rank_test_neg_mean_absolute_error  split0_test_r2  split1_test_r2  \
# 36                                  1        0.564383        0.574213
# 20                                  9        0.564045        0.565180
# 19                                 10        0.565235        0.565524
# 15                                  5        0.566265        0.566918
# 21                                 12        0.564478        0.564294
# 18                                 11        0.564670        0.565648
# 16                                  8        0.564978        0.565557
# 14                                  7        0.565526        0.566040
# 17                                 15        0.565492        0.563811
# 28                                 22        0.563467        0.562789
#
#     split2_test_r2  split3_test_r2  split4_test_r2  mean_test_r2  std_test_r2  \
# 36        0.575815        0.598274        0.581285      0.578794     0.011164
# 20        0.562648        0.591043        0.598429      0.576269     0.015279
# 19        0.561936        0.590483        0.597777      0.576191     0.014881
# 15        0.560692        0.587861        0.599128      0.576173     0.014745
# 21        0.562585        0.590932        0.598039      0.576065     0.015221
# 18        0.561591        0.588665        0.599386      0.575992     0.015169
# 16        0.559470        0.589866        0.599573      0.575889     0.015822
# 14        0.560312        0.587934        0.599239      0.575810     0.015082
# 17        0.559146        0.589530        0.600040      0.575604     0.016145
# 28        0.565956        0.590120        0.594212      0.575309     0.013865
#
#     rank_test_r2
# 36             1
# 20             2
# 19             3
# 15             4
# 21             5
# 18             6
# 16             7
# 14             8
# 17             9
# 28            10
#
# [10 rows x 35 columns]

# %%
y_predict = grid_search.best_estimator_.predict(X_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
grid_search.best_estimator_['regresor'].feature_importances_
# Out:
# array([1.03132217e-01, 1.51937022e-01, 5.80773386e-02, 1.34687699e-01,
#        1.10509870e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.39057193e-05, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.05398947e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.12623260e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.16906833e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.22305611e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.22157313e-04,
#        0.00000000e+00, 0.00000000e+00, 6.82242944e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.76915591e-02,
#        0.00000000e+00, 2.19077252e-04, 2.67288795e-04, 1.70399221e-03,
#        0.00000000e+00, 5.33010133e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 5.34332597e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 7.58574003e-04, 0.00000000e+00, 1.93500719e-03,
#        0.00000000e+00, 6.00599145e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.76485181e-01,
#        3.56276625e-02])

# %% [markdown]
# ### Random Search CV

# %%
param_grid_xgb = [
              {'regresor': [XGBRegressor(random_state = 0)],
               'regresor__xgb__learning_rate': [0.1],
               'regresor__xgb__max_depth': [7, 10, 15, 20],
               'regresor__xgb__min_child_weight': [10, 15, 20, 25],
               'regresor__xgb__colsample_bytree': [0.8, 0.9, 1],
               'regresor__xgb__n_estimators': [300, 400, 500, 600],
               'regresor__xgb__reg_alpha': [0.5, 0.2, 1],
               'regresor__xgb__reg_lambda': [2, 3, 5],
               'regresor__xgb__gamma': [1, 2, 3] #5184

              }]

# %%
grid_search_random = RandomizedSearchCV(model_pipe,
                                        param_grid_xgb,
                                        n_iter=10,
                                        cv=5,
                                        scoring=scores,
                                        random_state=0,
                                        refit= 'neg_root_mean_squared_error' ,
                                        n_jobs=-1
                           )
grid_search_random
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocesamiento',
#                                               ColumnTransformer(transformers=[('numerica',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('escalador',
#                                                                                                 StandardScaler())]),
#                                                                                ['latitude',
#                                                                                 'longitude',
#                                                                                 'bathrooms',
#                                                                                 'bedrooms',
#                                                                                 'beds']),
#                                                                               ('categorica',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strategy='most_frequent')),...
#                                          'regresor__xgb__learning_rate': [0.1],
#                                          'regresor__xgb__max_depth': [7, 10, 15,
#                                                                       20],
#                                          'regresor__xgb__min_child_weight': [10,
#                                                                              15,
#                                                                              20,
#                                                                              25],
#                                          'regresor__xgb__n_estimators': [300,
#                                                                          400,
#                                                                          500,
#                                                                          600],
#                                          'regresor__xgb__reg_alpha': [0.5, 0.2,
#                                                                       1],
#                                          'regresor__xgb__reg_lambda': [2, 3,
#                                                                        5]}],
#                    random_state=0, refit='neg_root_mean_squared_error',
#                    scoring=['neg_root_mean_squared_error',
#                             'neg_mean_absolute_error', 'r2'])

# %% [markdown]
# Esta celda se demora 13 minutos en ejecutar

# %%
# %%time
grid_search_random.fit(X_train,y_train)
joblib.dump(grid_search_random,
            '/content/drive/MyDrive/Diplomado big data/model_random.joblib')
# Out:
# [00:56:57] WARNING: ../src/learner.cc:767:
# Parameters: { "xgb__colsample_bytree", "xgb__gamma", "xgb__learning_rate", "xgb__max_depth", "xgb__min_child_weight", "xgb__n_estimators", "xgb__reg_alpha", "xgb__reg_lambda" } are not used.
#
# CPU times: user 3.93 s, sys: 99.2 ms, total: 4.03 s
# Wall time: 1min 1s
# ['/content/drive/MyDrive/Diplomado big data/model_random.joblib']

# %%
grid_search_random = joblib.load('/content/drive/MyDrive/Diplomado big data/model_random.joblib')

# %%
grid_search_random.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocesamiento',
#                                               ColumnTransformer(transformers=[('numerica',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('escalador',
#                                                                                                 StandardScaler())]),
#                                                                                ['latitude',
#                                                                                 'longitude',
#                                                                                 'bathrooms',
#                                                                                 'bedrooms',
#                                                                                 'beds']),
#                                                                               ('categorica',
#                                                                                Pipeline(steps=[('imputador',
#                                                                                                 SimpleImputer(strategy='most_frequent')),...
#                                          'regresor__xgb__learning_rate': [0.1],
#                                          'regresor__xgb__max_depth': [7, 10, 15,
#                                                                       20],
#                                          'regresor__xgb__min_child_weight': [10,
#                                                                              15,
#                                                                              20,
#                                                                              25],
#                                          'regresor__xgb__n_estimators': [300,
#                                                                          400,
#                                                                          500,
#                                                                          600],
#                                          'regresor__xgb__reg_alpha': [0.5, 0.2,
#                                                                       1],
#                                          'regresor__xgb__reg_lambda': [2, 3,
#                                                                        5]}],
#                    random_state=0, refit='neg_root_mean_squared_error',
#                    scoring=['neg_root_mean_squared_error',
#                             'neg_mean_absolute_error', 'r2'])>

# %%
grid_search_random.best_score_
# Out:
# -58.25446611235854

# %%
pd.DataFrame(grid_search_random.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.570840      0.511899         0.064739        0.023080
# 1       1.941262      0.005662         0.047774        0.003230
# 2       2.520787      0.621070         0.065453        0.024592
# 3       1.969217      0.042414         0.044220        0.000822
# 4       2.158622      0.418407         0.047483        0.006650
# 5       2.333217      0.519604         0.048765        0.010274
# 6       1.959156      0.037619         0.046879        0.004995
# 7       2.516839      0.526957         0.062420        0.022144
# 8       1.943271      0.016087         0.043661        0.001145
# 9       2.326292      0.468734         0.052117        0.017535
#
#   param_regresor__xgb__reg_lambda param_regresor__xgb__reg_alpha  \
# 0                               5                            0.2
# 1                               2                              1
# 2                               2                              1
# 3                               2                              1
# 4                               5                              1
# 5                               5                              1
# 6                               3                              1
# 7                               5                              1
# 8                               2                            0.2
# 9                               2                            0.2
#
#   param_regresor__xgb__n_estimators param_regresor__xgb__min_child_weight  \
# 0                               600                                    25
# 1                               400                                    10
# 2                               600                                    15
# 3                               500                                    20
# 4                               600                                    10
# 5                               600                                    20
# 6                               500                                    10
# 7                               400                                    15
# 8                               400                                    10
# 9                               500                                    25
#
#   param_regresor__xgb__max_depth param_regresor__xgb__learning_rate  ...  \
# 0                             15                                0.1  ...
# 1                             15                                0.1  ...
# 2                             20                                0.1  ...
# 3                             15                                0.1  ...
# 4                             15                                0.1  ...
# 5                             10                                0.1  ...
# 6                             20                                0.1  ...
# 7                             15                                0.1  ...
# 8                              7                                0.1  ...
# 9                              7                                0.1  ...
#
#   std_test_neg_mean_absolute_error rank_test_neg_mean_absolute_error  \
# 0                         0.471075                                 1
# 1                         0.471075                                 1
# 2                         0.471075                                 1
# 3                         0.471075                                 1
# 4                         0.471075                                 1
# 5                         0.471075                                 1
# 6                         0.471075                                 1
# 7                         0.471075                                 1
# 8                         0.471075                                 1
# 9                         0.471075                                 1
#
#   split0_test_r2 split1_test_r2  split2_test_r2  split3_test_r2  \
# 0       0.602252       0.586442        0.606108        0.622827
# 1       0.602252       0.586442        0.606108        0.622827
# 2       0.602252       0.586442        0.606108        0.622827
# 3       0.602252       0.586442        0.606108        0.622827
# 4       0.602252       0.586442        0.606108        0.622827
# 5       0.602252       0.586442        0.606108        0.622827
# 6       0.602252       0.586442        0.606108        0.622827
# 7       0.602252       0.586442        0.606108        0.622827
# 8       0.602252       0.586442        0.606108        0.622827
# 9       0.602252       0.586442        0.606108        0.622827
#
#    split4_test_r2  mean_test_r2  std_test_r2  rank_test_r2
# 0        0.619649      0.607456      0.01308             1
# 1        0.619649      0.607456      0.01308             1
# 2        0.619649      0.607456      0.01308             1
# 3        0.619649      0.607456      0.01308             1
# 4        0.619649      0.607456      0.01308             1
# 5        0.619649      0.607456      0.01308             1
# 6        0.619649      0.607456      0.01308             1
# 7        0.619649      0.607456      0.01308             1
# 8        0.619649      0.607456      0.01308             1
# 9        0.619649      0.607456      0.01308             1
#
# [10 rows x 38 columns]
